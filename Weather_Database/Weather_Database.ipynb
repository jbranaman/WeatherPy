# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import requests
from citipy import citipy 
import time 
from datetime import datetime 
from config import api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 783

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = str(city_weather["weather"][0]["description"]) 
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zwedru
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | wuwei
# Processing Record 5 of Set 1 | mehamn
# Processing Record 6 of Set 1 | geraldton
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | port blair
# Processing Record 9 of Set 1 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 10 of Set 1 | tuatapere
# Processing Record 11 of Set 1 | ternate
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | truth or consequences
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | yerbogachen
# Processing Record 17 of Set 1 | ancud
# Processing Record 18 of Set 1 | tautira
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | san andres
# Processing Record 21 of Set 1 | dzaoudzi
# Processing Record 22 of Set 1 | beringovskiy
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | miles city
# Processing Record 25 of Set 1 | szczecinek
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | longyearbyen
# Processing Record 30 of Set 1 | filadelfia
# Processing Record 31 of Set 1 | kendari
# Processing Record 32 of Set 1 | cockburn town
# Processing Record 33 of Set 1 | pangody
# Processing Record 34 of Set 1 | durban
# Processing Record 35 of Set 1 | havre-saint-pierre
# Processing Record 36 of Set 1 | matagami
# Processing Record 37 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 1 | nome
# Processing Record 39 of Set 1 | sao filipe
# Processing Record 40 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | khilok
# Processing Record 43 of Set 1 | sistranda
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | kibaya
# Processing Record 47 of Set 1 | palmer
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | bhalwal
# Processing Record 50 of Set 1 | slonim
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | chimore
# Processing Record 3 of Set 2 | lompoc
# Processing Record 4 of Set 2 | vao
# Processing Record 5 of Set 2 | nevsehir
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 2 | ostrovnoy
# Processing Record 9 of Set 2 | gunjur
# Processing Record 10 of Set 2 | catalina
# Processing Record 11 of Set 2 | yatou
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | padang
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | tokmak
# Processing Record 17 of Set 2 | bethel
# Processing Record 18 of Set 2 | carnarvon
# Processing Record 19 of Set 2 | nanortalik
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 2 | aklavik
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | praya
# Processing Record 25 of Set 2 | antsla
# Processing Record 26 of Set 2 | sirsa
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | grindavik
# Processing Record 29 of Set 2 | kasangulu
# Processing Record 30 of Set 2 | omboue
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | altay
# Processing Record 35 of Set 2 | saskylakh
# Processing Record 36 of Set 2 | kapaa
# Processing Record 37 of Set 2 | mataura
# Processing Record 38 of Set 2 | kodiak
# Processing Record 39 of Set 2 | keokuk
# Processing Record 40 of Set 2 | samatau
# City not found. Skipping...
# Processing Record 41 of Set 2 | quatre cocos
# Processing Record 42 of Set 2 | pevek
# Processing Record 43 of Set 2 | tomatlan
# Processing Record 44 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 2 | altamont
# Processing Record 46 of Set 2 | monrovia
# Processing Record 47 of Set 2 | east london
# Processing Record 48 of Set 2 | zhangjiakou
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 50 of Set 2 | buraydah
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | missoula
# Processing Record 3 of Set 3 | kutum
# Processing Record 4 of Set 3 | airai
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | shirokaya rechka
# Processing Record 8 of Set 3 | koroni
# Processing Record 9 of Set 3 | anadyr
# Processing Record 10 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 11 of Set 3 | nong kung si
# Processing Record 12 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 3 | slobozia
# Processing Record 14 of Set 3 | provideniya
# Processing Record 15 of Set 3 | sezze
# Processing Record 16 of Set 3 | qandala
# Processing Record 17 of Set 3 | rumuruti
# Processing Record 18 of Set 3 | avera
# Processing Record 19 of Set 3 | itaituba
# Processing Record 20 of Set 3 | yar-sale
# Processing Record 21 of Set 3 | rawson
# Processing Record 22 of Set 3 | ambikapur
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 3 | puerto escondido
# Processing Record 26 of Set 3 | korcula
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 28 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 3 | butaritari
# Processing Record 30 of Set 3 | muravlenko
# Processing Record 31 of Set 3 | san matias
# Processing Record 32 of Set 3 | labuan
# Processing Record 33 of Set 3 | moyo
# Processing Record 34 of Set 3 | vaitape
# Processing Record 35 of Set 3 | mtama
# Processing Record 36 of Set 3 | umm ruwabah
# City not found. Skipping...
# Processing Record 37 of Set 3 | chokurdakh
# Processing Record 38 of Set 3 | mahibadhoo
# Processing Record 39 of Set 3 | yulara
# Processing Record 40 of Set 3 | faanui
# Processing Record 41 of Set 3 | wajima
# Processing Record 42 of Set 3 | qasigiannguit
# Processing Record 43 of Set 3 | bilibino
# Processing Record 44 of Set 3 | marsabit
# Processing Record 45 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 3 | evensk
# Processing Record 47 of Set 3 | sibolga
# Processing Record 48 of Set 3 | saldanha
# Processing Record 49 of Set 3 | imeni poliny osipenko
# Processing Record 50 of Set 3 | jutai
# Processing Record 1 of Set 4 | udachnyy
# Processing Record 2 of Set 4 | hay river
# Processing Record 3 of Set 4 | sisimiut
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | vostok
# Processing Record 6 of Set 4 | port alfred
# Processing Record 7 of Set 4 | luderitz
# Processing Record 8 of Set 4 | pemba
# Processing Record 9 of Set 4 | buala
# Processing Record 10 of Set 4 | hobyo
# Processing Record 11 of Set 4 | namatanai
# Processing Record 12 of Set 4 | kattivakkam
# Processing Record 13 of Set 4 | geri
# Processing Record 14 of Set 4 | kavieng
# Processing Record 15 of Set 4 | paamiut
# Processing Record 16 of Set 4 | zhengjiatun
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | huarmey
# Processing Record 19 of Set 4 | hithadhoo
# Processing Record 20 of Set 4 | broken hill
# Processing Record 21 of Set 4 | izumo
# Processing Record 22 of Set 4 | jackson
# Processing Record 23 of Set 4 | mahebourg
# Processing Record 24 of Set 4 | glenwood springs
# Processing Record 25 of Set 4 | zharkent
# Processing Record 26 of Set 4 | college
# Processing Record 27 of Set 4 | alofi
# Processing Record 28 of Set 4 | bababe
# City not found. Skipping...
# Processing Record 29 of Set 4 | biak
# Processing Record 30 of Set 4 | arraial do cabo
# Processing Record 31 of Set 4 | isangel
# Processing Record 32 of Set 4 | khislavichi
# Processing Record 33 of Set 4 | xacmaz
# Processing Record 34 of Set 4 | ulladulla
# Processing Record 35 of Set 4 | cabo san lucas
# Processing Record 36 of Set 4 | kibondo
# Processing Record 37 of Set 4 | kruisfontein
# Processing Record 38 of Set 4 | codrington
# Processing Record 39 of Set 4 | neyshabur
# Processing Record 40 of Set 4 | kosh-agach
# Processing Record 41 of Set 4 | impfondo
# Processing Record 42 of Set 4 | dingle
# Processing Record 43 of Set 4 | nelson bay
# Processing Record 44 of Set 4 | coihaique
# Processing Record 45 of Set 4 | hoa binh
# Processing Record 46 of Set 4 | matara
# Processing Record 47 of Set 4 | pisco
# Processing Record 48 of Set 4 | bajil
# Processing Record 49 of Set 4 | bathsheba
# Processing Record 50 of Set 4 | stamsund
# City not found. Skipping...
# Processing Record 1 of Set 5 | sechura
# Processing Record 2 of Set 5 | srednekolymsk
# Processing Record 3 of Set 5 | bogo
# Processing Record 4 of Set 5 | manzanillo
# Processing Record 5 of Set 5 | kashi
# Processing Record 6 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 5 | cueramaro
# Processing Record 8 of Set 5 | tiksi
# Processing Record 9 of Set 5 | bisalpur
# Processing Record 10 of Set 5 | katsuura
# Processing Record 11 of Set 5 | luleburgaz
# Processing Record 12 of Set 5 | lata
# Processing Record 13 of Set 5 | yithion
# City not found. Skipping...
# Processing Record 14 of Set 5 | mount gambier
# Processing Record 15 of Set 5 | raga
# Processing Record 16 of Set 5 | sabzevar
# Processing Record 17 of Set 5 | hun
# Processing Record 18 of Set 5 | sungairaya
# Processing Record 19 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 5 | narsaq
# Processing Record 21 of Set 5 | sakakah
# Processing Record 22 of Set 5 | aksu
# Processing Record 23 of Set 5 | safaga
# Processing Record 24 of Set 5 | penzance
# Processing Record 25 of Set 5 | esperance
# Processing Record 26 of Set 5 | georgetown
# Processing Record 27 of Set 5 | coihueco
# Processing Record 28 of Set 5 | bandarbeyla
# Processing Record 29 of Set 5 | medea
# Processing Record 30 of Set 5 | rorvik
# Processing Record 31 of Set 5 | caucaia
# Processing Record 32 of Set 5 | ballina
# Processing Record 33 of Set 5 | vila
# Processing Record 34 of Set 5 | jining
# Processing Record 35 of Set 5 | sao felix do xingu
# Processing Record 36 of Set 5 | leningradskiy
# Processing Record 37 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 38 of Set 5 | ahipara
# Processing Record 39 of Set 5 | alaca
# Processing Record 40 of Set 5 | portobelo
# Processing Record 41 of Set 5 | cherskiy
# Processing Record 42 of Set 5 | lorengau
# Processing Record 43 of Set 5 | balkanabat
# Processing Record 44 of Set 5 | radford
# Processing Record 45 of Set 5 | zarichne
# Processing Record 46 of Set 5 | dabola
# Processing Record 47 of Set 5 | sao gabriel da cachoeira
# Processing Record 48 of Set 5 | hilo
# Processing Record 49 of Set 5 | almaznyy
# Processing Record 50 of Set 5 | whitianga
# Processing Record 1 of Set 6 | boditi
# Processing Record 2 of Set 6 | talnakh
# Processing Record 3 of Set 6 | kieta
# Processing Record 4 of Set 6 | souillac
# Processing Record 5 of Set 6 | goundam
# Processing Record 6 of Set 6 | huancabamba
# Processing Record 7 of Set 6 | naryan-mar
# Processing Record 8 of Set 6 | aswan
# Processing Record 9 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 10 of Set 6 | dubbo
# Processing Record 11 of Set 6 | alice springs
# Processing Record 12 of Set 6 | churapcha
# Processing Record 13 of Set 6 | suwannaphum
# Processing Record 14 of Set 6 | port hardy
# Processing Record 15 of Set 6 | majene
# Processing Record 16 of Set 6 | flin flon
# Processing Record 17 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 6 | havelock
# Processing Record 19 of Set 6 | khatanga
# Processing Record 20 of Set 6 | salalah
# Processing Record 21 of Set 6 | tuktoyaktuk
# Processing Record 22 of Set 6 | saint-louis
# Processing Record 23 of Set 6 | mahon
# Processing Record 24 of Set 6 | gamba
# Processing Record 25 of Set 6 | malindi
# Processing Record 26 of Set 6 | axim
# Processing Record 27 of Set 6 | alihe
# Processing Record 28 of Set 6 | naze
# Processing Record 29 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 6 | kitami
# Processing Record 31 of Set 6 | gornyy
# Processing Record 32 of Set 6 | clyde river
# Processing Record 33 of Set 6 | tagusao
# Processing Record 34 of Set 6 | torbay
# Processing Record 35 of Set 6 | illintsi
# Processing Record 36 of Set 6 | erzin
# Processing Record 37 of Set 6 | tongzi
# Processing Record 38 of Set 6 | utena
# Processing Record 39 of Set 6 | sinegorye
# Processing Record 40 of Set 6 | bhadra
# Processing Record 41 of Set 6 | arlit
# Processing Record 42 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 6 | te anau
# Processing Record 44 of Set 6 | marilia
# Processing Record 45 of Set 6 | avarua
# Processing Record 46 of Set 6 | verkh-usugli
# Processing Record 47 of Set 6 | ponta delgada
# Processing Record 48 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 6 | divnoye
# Processing Record 50 of Set 6 | kahului
# Processing Record 1 of Set 7 | tanda
# Processing Record 2 of Set 7 | adrar
# Processing Record 3 of Set 7 | zhigansk
# Processing Record 4 of Set 7 | coka
# Processing Record 5 of Set 7 | la ronge
# Processing Record 6 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 7 | mikkeli
# Processing Record 8 of Set 7 | saint george
# Processing Record 9 of Set 7 | xuddur
# Processing Record 10 of Set 7 | harer
# Processing Record 11 of Set 7 | port keats
# Processing Record 12 of Set 7 | lerwick
# Processing Record 13 of Set 7 | marzuq
# Processing Record 14 of Set 7 | byron bay
# Processing Record 15 of Set 7 | havoysund
# Processing Record 16 of Set 7 | buribay
# Processing Record 17 of Set 7 | manicore
# Processing Record 18 of Set 7 | bam
# Processing Record 19 of Set 7 | bari
# Processing Record 20 of Set 7 | manggar
# Processing Record 21 of Set 7 | dauphin
# Processing Record 22 of Set 7 | xining
# Processing Record 23 of Set 7 | shediac
# Processing Record 24 of Set 7 | safford
# Processing Record 25 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 26 of Set 7 | wahiawa
# Processing Record 27 of Set 7 | ceres
# Processing Record 28 of Set 7 | mariental
# Processing Record 29 of Set 7 | corbelia
# Processing Record 30 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 31 of Set 7 | obama
# Processing Record 32 of Set 7 | labuhan
# Processing Record 33 of Set 7 | olinda
# Processing Record 34 of Set 7 | karpathos
# Processing Record 35 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 7 | hualmay
# Processing Record 37 of Set 7 | rocha
# Processing Record 38 of Set 7 | los llanos de aridane
# Processing Record 39 of Set 7 | komsomolskiy
# Processing Record 40 of Set 7 | smalininkai
# Processing Record 41 of Set 7 | maswa
# Processing Record 42 of Set 7 | suao
# City not found. Skipping...
# Processing Record 43 of Set 7 | cabinda
# Processing Record 44 of Set 7 | nishihara
# Processing Record 45 of Set 7 | cayenne
# Processing Record 46 of Set 7 | belyy yar
# Processing Record 47 of Set 7 | sardarshahr
# Processing Record 48 of Set 7 | dunedin
# Processing Record 49 of Set 7 | hasaki
# Processing Record 50 of Set 7 | ormara
# Processing Record 1 of Set 8 | solnechnyy
# Processing Record 2 of Set 8 | sri aman
# Processing Record 3 of Set 8 | prosec
# Processing Record 4 of Set 8 | ilo
# Processing Record 5 of Set 8 | hare bay
# Processing Record 6 of Set 8 | waikuku
# Processing Record 7 of Set 8 | chapais
# Processing Record 8 of Set 8 | taksimo
# Processing Record 9 of Set 8 | tarko-sale
# Processing Record 10 of Set 8 | umm kaddadah
# Processing Record 11 of Set 8 | mazyr
# Processing Record 12 of Set 8 | general roca
# Processing Record 13 of Set 8 | ponta do sol
# Processing Record 14 of Set 8 | igbon
# Processing Record 15 of Set 8 | guspini
# Processing Record 16 of Set 8 | atasu
# Processing Record 17 of Set 8 | pitimbu
# Processing Record 18 of Set 8 | henties bay
# Processing Record 19 of Set 8 | mitu
# Processing Record 20 of Set 8 | vredendal
# Processing Record 21 of Set 8 | san cristobal
# Processing Record 22 of Set 8 | murgab
# Processing Record 23 of Set 8 | tasiilaq
# Processing Record 24 of Set 8 | sept-iles
# Processing Record 25 of Set 8 | skjervoy
# Processing Record 26 of Set 8 | meridian
# Processing Record 27 of Set 8 | touros
# Processing Record 28 of Set 8 | ust-kuyga
# Processing Record 29 of Set 8 | lafiagi
# Processing Record 30 of Set 8 | coquimbo
# Processing Record 31 of Set 8 | alyangula
# Processing Record 32 of Set 8 | springdale
# Processing Record 33 of Set 8 | yako
# Processing Record 34 of Set 8 | mwene-ditu
# Processing Record 35 of Set 8 | lasa
# Processing Record 36 of Set 8 | madiun
# Processing Record 37 of Set 8 | lago da pedra
# Processing Record 38 of Set 8 | fort frances
# Processing Record 39 of Set 8 | hailar
# Processing Record 40 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 8 | halmstad
# Processing Record 42 of Set 8 | ouesso
# Processing Record 43 of Set 8 | faya
# Processing Record 44 of Set 8 | vila velha
# Processing Record 45 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 8 | stolin
# Processing Record 47 of Set 8 | pangkalanbuun
# Processing Record 48 of Set 8 | diffa
# Processing Record 49 of Set 8 | hendijan
# City not found. Skipping...
# Processing Record 50 of Set 8 | cidreira
# Processing Record 1 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 2 of Set 9 | henzada
# City not found. Skipping...
# Processing Record 3 of Set 9 | dudinka
# Processing Record 4 of Set 9 | kapit
# Processing Record 5 of Set 9 | grays
# Processing Record 6 of Set 9 | murray bridge
# Processing Record 7 of Set 9 | victoria
# Processing Record 8 of Set 9 | tilichiki
# Processing Record 9 of Set 9 | sitka
# Processing Record 10 of Set 9 | entre rios
# Processing Record 11 of Set 9 | oktyabrskoye
# Processing Record 12 of Set 9 | porto santo
# Processing Record 13 of Set 9 | san quintin
# Processing Record 14 of Set 9 | shchuchye
# City not found. Skipping...
# Processing Record 15 of Set 9 | ilulissat
# Processing Record 16 of Set 9 | mayo
# Processing Record 17 of Set 9 | banda aceh
# Processing Record 18 of Set 9 | pemberton
# Processing Record 19 of Set 9 | kamaishi
# Processing Record 20 of Set 9 | shangrao
# Processing Record 21 of Set 9 | picos
# Processing Record 22 of Set 9 | nacogdoches
# Processing Record 23 of Set 9 | innisfail
# Processing Record 24 of Set 9 | hambantota
# Processing Record 25 of Set 9 | santa rosa
# Processing Record 26 of Set 9 | laguna
# Processing Record 27 of Set 9 | chuy
# Processing Record 28 of Set 9 | sol-iletsk
# Processing Record 29 of Set 9 | mecca
# Processing Record 30 of Set 9 | yeppoon
# Processing Record 31 of Set 9 | mombetsu
# Processing Record 32 of Set 9 | vrangel
# Processing Record 33 of Set 9 | canavieiras
# Processing Record 34 of Set 9 | emba
# Processing Record 35 of Set 9 | anloga
# Processing Record 36 of Set 9 | lander
# Processing Record 37 of Set 9 | najran
# Processing Record 38 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 9 | nanded
# City not found. Skipping...
# Processing Record 40 of Set 9 | aasiaat
# Processing Record 41 of Set 9 | lucea
# Processing Record 42 of Set 9 | cherlak
# Processing Record 43 of Set 9 | talcahuano
# Processing Record 44 of Set 9 | uberlandia
# Processing Record 45 of Set 9 | mangai
# Processing Record 46 of Set 9 | sangmelima
# Processing Record 47 of Set 9 | moose factory
# Processing Record 48 of Set 9 | gasa
# Processing Record 49 of Set 9 | grand gaube
# Processing Record 50 of Set 9 | springfield
# Processing Record 1 of Set 10 | goure
# Processing Record 2 of Set 10 | atar
# Processing Record 3 of Set 10 | dolores
# Processing Record 4 of Set 10 | urusha
# Processing Record 5 of Set 10 | tatarsk
# Processing Record 6 of Set 10 | fortuna
# Processing Record 7 of Set 10 | nizhnevartovsk
# Processing Record 8 of Set 10 | konigs wusterhausen
# Processing Record 9 of Set 10 | zhadovka
# Processing Record 10 of Set 10 | atambua
# Processing Record 11 of Set 10 | libreville
# Processing Record 12 of Set 10 | arica
# Processing Record 13 of Set 10 | mareeba
# Processing Record 14 of Set 10 | marienburg
# Processing Record 15 of Set 10 | bambous virieux
# Processing Record 16 of Set 10 | chemainus
# Processing Record 17 of Set 10 | coatlan
# City not found. Skipping...
# Processing Record 18 of Set 10 | leshukonskoye
# Processing Record 19 of Set 10 | malpe
# Processing Record 20 of Set 10 | lavrentiya
# Processing Record 21 of Set 10 | maningrida
# Processing Record 22 of Set 10 | hammerfest
# Processing Record 23 of Set 10 | pasni
# Processing Record 24 of Set 10 | okakarara
# Processing Record 25 of Set 10 | dangtu
# Processing Record 26 of Set 10 | bara
# Processing Record 27 of Set 10 | alvdal
# Processing Record 28 of Set 10 | sovetskiy
# Processing Record 29 of Set 10 | posse
# Processing Record 30 of Set 10 | papasquiaro
# City not found. Skipping...
# Processing Record 31 of Set 10 | panama city
# Processing Record 32 of Set 10 | muzquiz
# City not found. Skipping...
# Processing Record 33 of Set 10 | opuwo
# Processing Record 34 of Set 10 | gat
# Processing Record 35 of Set 10 | lujan
# Processing Record 36 of Set 10 | sangar
# Processing Record 37 of Set 10 | suihua
# Processing Record 38 of Set 10 | gondanglegi
# Processing Record 39 of Set 10 | itaobim
# Processing Record 40 of Set 10 | palauig
# Processing Record 41 of Set 10 | camacha
# Processing Record 42 of Set 10 | george town
# Processing Record 43 of Set 10 | onalaska
# Processing Record 44 of Set 10 | vila franca do campo
# Processing Record 45 of Set 10 | shellbrook
# Processing Record 46 of Set 10 | nautla
# Processing Record 47 of Set 10 | hampton
# Processing Record 48 of Set 10 | fonte boa
# Processing Record 49 of Set 10 | tupik
# Processing Record 50 of Set 10 | kvitok
# Processing Record 1 of Set 11 | poum
# Processing Record 2 of Set 11 | akdepe
# Processing Record 3 of Set 11 | sidi qasim
# City not found. Skipping...
# Processing Record 4 of Set 11 | pittsburg
# Processing Record 5 of Set 11 | olafsvik
# Processing Record 6 of Set 11 | gizo
# Processing Record 7 of Set 11 | bestobe
# Processing Record 8 of Set 11 | coahuayana
# Processing Record 9 of Set 11 | ayorou
# Processing Record 10 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 11 | san ramon
# Processing Record 12 of Set 11 | bowen
# Processing Record 13 of Set 11 | pleshanovo
# Processing Record 14 of Set 11 | caravelas
# Processing Record 15 of Set 11 | prince rupert
# Processing Record 16 of Set 11 | vidim
# Processing Record 17 of Set 11 | hamilton
# Processing Record 18 of Set 11 | jian
# Processing Record 19 of Set 11 | cozumel
# Processing Record 20 of Set 11 | bunia
# Processing Record 21 of Set 11 | isla mujeres
# Processing Record 22 of Set 11 | roald
# Processing Record 23 of Set 11 | johi
# Processing Record 24 of Set 11 | pravia
# Processing Record 25 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 26 of Set 11 | port hedland
# Processing Record 27 of Set 11 | soe
# Processing Record 28 of Set 11 | klaksvik
# Processing Record 29 of Set 11 | kemijarvi
# Processing Record 30 of Set 11 | husavik
# Processing Record 31 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 32 of Set 11 | wattegama
# Processing Record 33 of Set 11 | wewak
# Processing Record 34 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 35 of Set 11 | poshekhonye
# Processing Record 36 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 11 | champerico
# Processing Record 38 of Set 11 | laela
# Processing Record 39 of Set 11 | sioux lookout
# Processing Record 40 of Set 11 | tomaszow lubelski
# Processing Record 41 of Set 11 | constitucion
# Processing Record 42 of Set 11 | cumberland
# Processing Record 43 of Set 11 | sola
# Processing Record 44 of Set 11 | colares
# Processing Record 45 of Set 11 | winchester
# Processing Record 46 of Set 11 | valentin gomez farias
# Processing Record 47 of Set 11 | kennewick
# Processing Record 48 of Set 11 | viedma
# Processing Record 49 of Set 11 | kholbon
# Processing Record 50 of Set 11 | mahanoro
# Processing Record 1 of Set 12 | varhaug
# Processing Record 2 of Set 12 | tombouctou
# Processing Record 3 of Set 12 | diego de almagro
# Processing Record 4 of Set 12 | evanston
# Processing Record 5 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 12 | zhangye
# Processing Record 7 of Set 12 | altus
# Processing Record 8 of Set 12 | itarema
# Processing Record 9 of Set 12 | hudson bay
# Processing Record 10 of Set 12 | singaraja
# Processing Record 11 of Set 12 | juneau
# Processing Record 12 of Set 12 | asau
# Processing Record 13 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 12 | bagdarin
# Processing Record 15 of Set 12 | serabu
# Processing Record 16 of Set 12 | calvinia
# Processing Record 17 of Set 12 | cap malheureux
# Processing Record 18 of Set 12 | taoudenni
# Processing Record 19 of Set 12 | vestmannaeyjar
# Processing Record 20 of Set 12 | samarai
# Processing Record 21 of Set 12 | kampene
# Processing Record 22 of Set 12 | banff
# Processing Record 23 of Set 12 | lumeje
# Processing Record 24 of Set 12 | port macquarie
# Processing Record 25 of Set 12 | terra santa
# Processing Record 26 of Set 12 | porto novo
# Processing Record 27 of Set 12 | sao joao da barra
# Processing Record 28 of Set 12 | nantucket
# Processing Record 29 of Set 12 | kalino
# Processing Record 30 of Set 12 | aykhal
# Processing Record 31 of Set 12 | pinehurst
# Processing Record 32 of Set 12 | ayan
# Processing Record 33 of Set 12 | nago
# Processing Record 34 of Set 12 | rudnya
# Processing Record 35 of Set 12 | pacific grove
# Processing Record 36 of Set 12 | padra
# Processing Record 37 of Set 12 | nador
# Processing Record 38 of Set 12 | obihiro
# Processing Record 39 of Set 12 | kimberley
# Processing Record 40 of Set 12 | sokolniki
# Processing Record 41 of Set 12 | newport
# Processing Record 42 of Set 12 | bensonville
# Processing Record 43 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 44 of Set 12 | broome
# Processing Record 45 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 46 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 12 | brownsburg
# Processing Record 48 of Set 12 | boende
# Processing Record 49 of Set 12 | waingapu
# Processing Record 50 of Set 12 | shiyan
# Processing Record 1 of Set 13 | qax
# Processing Record 2 of Set 13 | kirakira
# Processing Record 3 of Set 13 | kenai
# Processing Record 4 of Set 13 | gotsu
# Processing Record 5 of Set 13 | beloha
# Processing Record 6 of Set 13 | thung song
# Processing Record 7 of Set 13 | norman wells
# Processing Record 8 of Set 13 | guerrero negro
# Processing Record 9 of Set 13 | tukrah
# Processing Record 10 of Set 13 | kalispell
# Processing Record 11 of Set 13 | kozhva
# Processing Record 12 of Set 13 | vitim
# Processing Record 13 of Set 13 | honningsvag
# Processing Record 14 of Set 13 | verkhnyaya inta
# Processing Record 15 of Set 13 | otse
# Processing Record 16 of Set 13 | khetri
# Processing Record 17 of Set 13 | port said
# Processing Record 18 of Set 13 | chipinge
# Processing Record 19 of Set 13 | kupang
# Processing Record 20 of Set 13 | weinan
# Processing Record 21 of Set 13 | kuantan
# Processing Record 22 of Set 13 | polovinnoye
# Processing Record 23 of Set 13 | oistins
# Processing Record 24 of Set 13 | ritchie
# Processing Record 25 of Set 13 | dargaville
# Processing Record 26 of Set 13 | nemuro
# Processing Record 27 of Set 13 | farafangana
# Processing Record 28 of Set 13 | utiel
# Processing Record 29 of Set 13 | bull savanna
# Processing Record 30 of Set 13 | kirovskiy
# Processing Record 31 of Set 13 | am timan
# Processing Record 32 of Set 13 | viransehir
# Processing Record 33 of Set 13 | korem
# Processing Record 34 of Set 13 | turukhansk
# Processing Record 35 of Set 13 | reims
# Processing Record 36 of Set 13 | yarovoye
# Processing Record 37 of Set 13 | letlhakeng
# Processing Record 38 of Set 13 | sur
# Processing Record 39 of Set 13 | popondetta
# Processing Record 40 of Set 13 | rio gallegos
# Processing Record 41 of Set 13 | volchanets
# Processing Record 42 of Set 13 | praia da vitoria
# Processing Record 43 of Set 13 | saint-augustin
# Processing Record 44 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 13 | nara
# Processing Record 46 of Set 13 | camana
# Processing Record 47 of Set 13 | kotlas
# Processing Record 48 of Set 13 | tripoli
# Processing Record 49 of Set 13 | aconibe
# Processing Record 50 of Set 13 | kavaratti
# Processing Record 1 of Set 14 | harper
# Processing Record 2 of Set 14 | cankuzo
# Processing Record 3 of Set 14 | gejiu
# Processing Record 4 of Set 14 | rantepao
# Processing Record 5 of Set 14 | beruwala
# Processing Record 6 of Set 14 | kotdwara
# Processing Record 7 of Set 14 | ambilobe
# Processing Record 8 of Set 14 | hervey bay
# Processing Record 9 of Set 14 | half moon bay
# Processing Record 10 of Set 14 | pangnirtung
# Processing Record 11 of Set 14 | tocopilla
# Processing Record 12 of Set 14 | calabozo
# Processing Record 13 of Set 14 | carutapera
# Processing Record 14 of Set 14 | baddomalhi
# Processing Record 15 of Set 14 | lourdes
# Processing Record 16 of Set 14 | saint-georges
# Processing Record 17 of Set 14 | krasnyy chikoy
# Processing Record 18 of Set 14 | ulaangom
# Processing Record 19 of Set 14 | denpasar
# Processing Record 20 of Set 14 | beira
# Processing Record 21 of Set 14 | seoul
# Processing Record 22 of Set 14 | fairbanks
# Processing Record 23 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 24 of Set 14 | acatlan
# Processing Record 25 of Set 14 | mamallapuram
# Processing Record 26 of Set 14 | jimo
# Processing Record 27 of Set 14 | maniitsoq
# Processing Record 28 of Set 14 | namibe
# Processing Record 29 of Set 14 | port lincoln
# Processing Record 30 of Set 14 | poso
# Processing Record 31 of Set 14 | margate
# Processing Record 32 of Set 14 | karratha
# Processing Record 33 of Set 14 | mogadishu
# Processing Record 34 of Set 14 | naugarzan
# City not found. Skipping...
# Processing Record 35 of Set 14 | maltahohe
# Processing Record 36 of Set 14 | sarkand
# Processing Record 37 of Set 14 | pachperwa
# Processing Record 38 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 39 of Set 14 | litoral del san juan
# City not found. Skipping...
# Processing Record 40 of Set 14 | vikhorevka
# Processing Record 41 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 14 | moindou
# Processing Record 43 of Set 14 | dwarahat
# Processing Record 44 of Set 14 | milici
# Processing Record 45 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 14 | puqi
# Processing Record 47 of Set 14 | bocana
# Processing Record 48 of Set 14 | warwick
# Processing Record 49 of Set 14 | himora
# City not found. Skipping...
# Processing Record 50 of Set 14 | lagoa
# Processing Record 1 of Set 15 | gaozhou
# Processing Record 2 of Set 15 | uvat
# Processing Record 3 of Set 15 | beboto
# Processing Record 4 of Set 15 | khandbari
# Processing Record 5 of Set 15 | pirapo
# Processing Record 6 of Set 15 | san patricio
# Processing Record 7 of Set 15 | bosansko grahovo
# Processing Record 8 of Set 15 | berlevag
# Processing Record 9 of Set 15 | bilma
# Processing Record 10 of Set 15 | floro
# Processing Record 11 of Set 15 | jalu
# Processing Record 12 of Set 15 | leh
# Processing Record 13 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 14 of Set 15 | aksarka
# Processing Record 15 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 16 of Set 15 | sujiatun
# Processing Record 17 of Set 15 | limbang
# Processing Record 18 of Set 15 | burica
# City not found. Skipping...
# Processing Record 19 of Set 15 | morwell
# Processing Record 20 of Set 15 | kilifi
# Processing Record 21 of Set 15 | berdigestyakh
# Processing Record 22 of Set 15 | clearlake
# Processing Record 23 of Set 15 | chanderi
# Processing Record 24 of Set 15 | maralal
# Processing Record 25 of Set 15 | forest grove
# Processing Record 26 of Set 15 | ossora
# Processing Record 27 of Set 15 | ovsyanka
# Processing Record 28 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 29 of Set 15 | barinas
# Processing Record 30 of Set 15 | caraballeda
# Processing Record 31 of Set 15 | amapa
# Processing Record 32 of Set 15 | san luis
# Processing Record 33 of Set 15 | jerantut
# Processing Record 34 of Set 15 | pinega
# Processing Record 35 of Set 15 | meadow lake
# Processing Record 36 of Set 15 | shache
# Processing Record 37 of Set 15 | nuuk
# Processing Record 38 of Set 15 | porto velho
# Processing Record 39 of Set 15 | birmitrapur
# Processing Record 40 of Set 15 | kissidougou
# Processing Record 41 of Set 15 | vanimo
# Processing Record 42 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 15 | lewiston
# Processing Record 44 of Set 15 | qui nhon
# Processing Record 45 of Set 15 | matamoros
# Processing Record 46 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 47 of Set 15 | marechal floriano
# Processing Record 48 of Set 15 | inuvik
# Processing Record 49 of Set 15 | el alto
# Processing Record 50 of Set 15 | esmeraldas
# Processing Record 1 of Set 16 | nioki
# Processing Record 2 of Set 16 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 16 | winnipeg
# Processing Record 4 of Set 16 | la paz
# Processing Record 5 of Set 16 | north bend
# Processing Record 6 of Set 16 | cukai
# Processing Record 7 of Set 16 | gradsko
# Processing Record 8 of Set 16 | kaeo
# Processing Record 9 of Set 16 | korla
# Processing Record 10 of Set 16 | goderich
# Processing Record 11 of Set 16 | sinnamary
# Processing Record 12 of Set 16 | kharp
# Processing Record 13 of Set 16 | dromolaxia
# Processing Record 14 of Set 16 | santa ana
# Processing Record 15 of Set 16 | kysyl-syr
# Processing Record 16 of Set 16 | dong xoai
# Processing Record 17 of Set 16 | hilpoltstein
# Processing Record 18 of Set 16 | susanville
# Processing Record 19 of Set 16 | vardo
# Processing Record 20 of Set 16 | careiro da varzea
# Processing Record 21 of Set 16 | mmabatho
# Processing Record 22 of Set 16 | guelengdeng
# City not found. Skipping...
# Processing Record 23 of Set 16 | dakar
# Processing Record 24 of Set 16 | cumaribo
# City not found. Skipping...
# Processing Record 25 of Set 16 | khani
# Processing Record 26 of Set 16 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 16 | kishapu
# Processing Record 28 of Set 16 | qiryat shemona
# Processing Record 29 of Set 16 | quelimane
# Processing Record 30 of Set 16 | jinchang
# Processing Record 31 of Set 16 | kidal
# Processing Record 32 of Set 16 | bose
# Processing Record 33 of Set 16 | butembo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0      Zwedru   6.0667   -8.1281          few clouds     71.53        96
# 1       Bluff -46.6000  168.3333     overcast clouds     62.80        80
# 2    Thompson  55.7435  -97.8558     overcast clouds     14.16        73
# 3       Wuwei  37.9281  102.6414           clear sky     17.10        63
# 4      Mehamn  71.0357   27.8492     overcast clouds     20.10        88
# 5   Geraldton -28.7667  114.6000           clear sky     71.13        68
# 6  Kaitangata -46.2817  169.8464     overcast clouds     59.83        86
# 7  Port Blair  11.6667   92.7500                mist     75.24        88
# 8   Tuatapere -46.1333  167.6833     overcast clouds     62.82        64
# 9     Ternate   0.8000  127.4000     overcast clouds     81.54        78
#
#    Cloudiness  Wind Speed Country                 Date
# 0          16        1.23      LR  2022-02-09 00:35:26
# 1         100       13.24      NZ  2022-02-09 00:31:59
# 2         100       13.80      CA  2022-02-09 00:30:31
# 3           2        4.16      CN  2022-02-09 00:35:27
# 4         100       13.80      NO  2022-02-09 00:35:27
# 5           0       14.97      AU  2022-02-09 00:31:20
# 6         100       11.01      NZ  2022-02-09 00:34:42
# 7          40        1.14      IN  2022-02-09 00:35:28
# 8         100        4.07      NZ  2022-02-09 00:35:29
# 9         100        6.24      ID  2022-02-09 00:35:29

# %%
len(city_data)
# Out:
# 712

# %%
city_data_modified = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[city_data_modified]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Zwedru      LR   6.0667   -8.1281     71.53        96          16
# 1       Bluff      NZ -46.6000  168.3333     62.80        80         100
# 2    Thompson      CA  55.7435  -97.8558     14.16        73         100
# 3       Wuwei      CN  37.9281  102.6414     17.10        63           2
# 4      Mehamn      NO  71.0357   27.8492     20.10        88         100
# 5   Geraldton      AU -28.7667  114.6000     71.13        68           0
# 6  Kaitangata      NZ -46.2817  169.8464     59.83        86         100
# 7  Port Blair      IN  11.6667   92.7500     75.24        88          40
# 8   Tuatapere      NZ -46.1333  167.6833     62.82        64         100
# 9     Ternate      ID   0.8000  127.4000     81.54        78         100
#
#    Wind Speed Current Description
# 0        1.23          few clouds
# 1       13.24     overcast clouds
# 2       13.80     overcast clouds
# 3        4.16           clear sky
# 4       13.80     overcast clouds
# 5       14.97           clear sky
# 6       11.01     overcast clouds
# 7        1.14                mist
# 8        4.07     overcast clouds
# 9        6.24     overcast clouds

# %%
output_data_file = "WeatherPy_database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
